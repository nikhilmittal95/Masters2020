# %%
from google.colab import files
i= files.upload()
# Out:
#      <input type="file" id="files-b79045af-acb0-4bee-998d-f2ce7890c918" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b79045af-acb0-4bee-998d-f2ce7890c918">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving insurance_data.csv to insurance_data.csv

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('insurance_data.csv')

# %%
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
plt.scatter(df.age,df.bought_insurance,marker='+',color='red')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df[['age']],df.bought_insurance,test_size=0.1)

# %%
X_train
# Out:
#     age
# 19   18
# 1    25
# 6    55
# 22   40
# 11   28
# 10   18
# 12   27
# 21   26
# 13   29
# 9    61
# 18   19
# 15   55
# 4    46
# 5    56
# 8    62
# 26   23
# 16   25
# 3    52
# 20   21
# 24   50
# 23   45
# 0    22
# 2    47
# 17   58

# %%
X_test
# Out:
#     age
# 7    60
# 14   49
# 25   54

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
X_test
# Out:
#     age
# 7    60
# 14   49
# 25   54

# %%
y_predicted = model.predict(X_test)
model.predict_proba(X_test)
# Out:
# array([[0.07433747, 0.92566253],
#        [0.24190658, 0.75809342],
#        [0.14562145, 0.85437855]])

# %%
y_predicted
# Out:
# array([1, 1, 1])

# %%
model.score(X_test,y_test)
# Out:
# 1.0

# %%
X_test
# Out:
#     age
# 7    60
# 14   49
# 25   54

# %%
model.coef_
# Out:
# array([[0.12542177]])

# %%
model.intercept_
# Out:
# array([-5.00341189])

# %%
import math
def sigmoid(x):
  return 1 / (1 + math.exp(-x))
def prediction_function(age):
    z = 0.042 * age - 1.53 # 0.04150133 ~ 0.042 and -1.52726963 ~ -1.53
    y = sigmoid(z)
    return y
age = 35
prediction_function(age)
# Out:
# 0.4850044983805899

# %%
age = 43
prediction_function(age)
# Out:
# 0.568565299077705
