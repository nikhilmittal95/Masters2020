# %%
import numpy as np
import pandas as pd

import os
print(os.listdir("C:/Users/nikhi/Downloads/Rain"))
# Out:
# ['sample_dask.py', 'sample_solution.csv', 'test', 'train']

# %%
INPUT_WIDTH = 19
N_FEATURES = 22

# taken from http://simaaron.github.io/Estimating-rainfall-from-weather-radar-readings-using-recurrent-neural-networks/
THRESHOLD = 73

# %%
train_df = pd.read_csv("C:/Users/nikhi/Downloads/Rain/train/train.csv")
train_df[train_df.columns[1:]] = train_df[train_df.columns[1:]].astype(np.float32)
train_df.head(20)
# Out:
#     Id  minutes_past  radardist_km   Ref  Ref_5x5_10th  Ref_5x5_50th  \
# 0    1           3.0          10.0   NaN           NaN           NaN
# 1    1          16.0          10.0   NaN           NaN           NaN
# 2    1          25.0          10.0   NaN           NaN           NaN
# 3    1          35.0          10.0   NaN           NaN           NaN
# 4    1          45.0          10.0   NaN           NaN           NaN
# 5    1          55.0          10.0   NaN           NaN           NaN
# 6    2           1.0           2.0   9.0           5.0           7.5
# 7    2           6.0           2.0  26.5          22.5          25.5
# 8    2          11.0           2.0  21.5          15.5          20.5
# 9    2          16.0           2.0  18.0          14.0          17.5
# 10   2          21.0           2.0  24.5          16.5          21.0
# 11   2          26.0           2.0  12.0          12.0          16.0
# 12   2          31.0           2.0  22.5          19.0          22.0
# 13   2          37.0           2.0  14.0          14.0          18.5
# 14   2          42.0           2.0  12.0          11.0          12.5
# 15   2          47.0           2.0   1.5           3.5           7.0
# 16   2          53.0           2.0  16.0          14.5          18.0
# 17   2          58.0           2.0  22.0          16.5          22.5
# 18   3           4.0          10.0   NaN           NaN           NaN
# 19   3           9.0          10.0   NaN           NaN           NaN
#
#     Ref_5x5_90th  RefComposite  RefComposite_5x5_10th  RefComposite_5x5_50th  \
# 0            NaN           NaN                    NaN                    NaN
# 1            NaN           NaN                    NaN                    NaN
# 2            NaN           NaN                    NaN                    NaN
# 3            NaN           NaN                    NaN                    NaN
# 4            NaN           NaN                    NaN                    NaN
# 5            NaN           NaN                    NaN                    NaN
# 6           10.5          15.0                   10.5                   16.5
# 7           31.5          26.5                   26.5                   28.5
# 8           25.0          26.5                   23.5                   25.0
# 9           21.0          20.5                   18.0                   20.5
# 10          24.5          24.5                   21.0                   24.0
# 11          20.0          16.5                   17.0                   19.0
# 12          25.0          26.0                   23.5                   25.5
# 13          21.0          19.5                   20.0                   21.0
# 14          17.0          19.5                   18.0                   21.0
# 15          10.5          18.0                   16.5                   18.5
# 16          23.5          28.0                   23.5                   26.5
# 17          26.5          31.5                   26.5                   29.0
# 18           NaN           NaN                    NaN                    NaN
# 19           NaN           NaN                    NaN                    NaN
#
#     ...  RhoHV_5x5_90th     Zdr  Zdr_5x5_10th  Zdr_5x5_50th  Zdr_5x5_90th  \
# 0   ...             NaN     NaN           NaN           NaN           NaN
# 1   ...             NaN     NaN           NaN           NaN           NaN
# 2   ...             NaN     NaN           NaN           NaN           NaN
# 3   ...             NaN     NaN           NaN           NaN           NaN
# 4   ...             NaN     NaN           NaN           NaN           NaN
# 5   ...             NaN     NaN           NaN           NaN           NaN
# 6   ...        0.998333  0.3750       -0.1250        0.3125        0.8750
# 7   ...        1.005000  0.0625       -0.1875        0.2500        0.6875
# 8   ...        1.001667  0.3125       -0.0625        0.3125        0.6250
# 9   ...        1.001667  0.2500        0.1250        0.3750        0.6875
# 10  ...        0.998333  0.2500        0.0625        0.1875        0.5625
# 11  ...        0.998333  0.5625        0.2500        0.4375        0.6875
# 12  ...        1.001667  0.0000       -0.1875        0.2500        0.6250
# 13  ...        0.998333  0.5000        0.1875        0.4375        0.8125
# 14  ...        0.998333  0.6250        0.3750        0.6250        0.8750
# 15  ...        0.998333  0.3750        0.1875        0.5000        0.6875
# 16  ...        0.998333  0.8750        0.6250        0.9375        1.3750
# 17  ...        1.001667  0.3750        0.1875        0.3750        0.8750
# 18  ...             NaN     NaN           NaN           NaN           NaN
# 19  ...             NaN     NaN           NaN           NaN           NaN
#
#          Kdp  Kdp_5x5_10th  Kdp_5x5_50th  Kdp_5x5_90th   Expected
# 0        NaN           NaN           NaN           NaN   0.254000
# 1        NaN           NaN           NaN           NaN   0.254000
# 2        NaN           NaN           NaN           NaN   0.254000
# 3        NaN           NaN           NaN           NaN   0.254000
# 4        NaN           NaN           NaN           NaN   0.254000
# 5        NaN           NaN           NaN           NaN   0.254000
# 6   1.059998     -1.410004     -0.350006      1.059998   1.016001
# 7        NaN           NaN           NaN      1.409988   1.016001
# 8   0.349991           NaN     -0.350006      1.759995   1.016001
# 9   0.349991     -1.059998      0.000000      1.059998   1.016001
# 10 -0.350006     -1.059998     -0.350006      1.759995   1.016001
# 11 -1.760010     -1.760010     -0.350006      0.709991   1.016001
# 12 -1.059998     -2.120010     -0.710007      0.349991   1.016001
# 13  0.000000     -1.760010     -0.350006      1.059998   1.016001
# 14 -0.350006     -0.350006      0.000000      0.349991   1.016001
# 15  0.349991     -2.110001     -0.350006      1.059998   1.016001
# 16 -0.350006     -1.410004     -0.350006      2.119995   1.016001
# 17 -1.410004           NaN     -0.350006      0.699997   1.016001
# 18       NaN           NaN           NaN           NaN  26.162014
# 19       NaN           NaN           NaN           NaN  26.162014
#
# [20 rows x 24 columns]

# %%
train_ids = train_df[~np.isnan(train_df.Ref)].Id.unique()
train_new = train_df[np.in1d(train_df.Id, train_ids)]
del train_df, train_ids
train_new.head()
# Out:
#     Id  minutes_past  radardist_km   Ref  Ref_5x5_10th  Ref_5x5_50th  \
# 6    2           1.0           2.0   9.0           5.0           7.5
# 7    2           6.0           2.0  26.5          22.5          25.5
# 8    2          11.0           2.0  21.5          15.5          20.5
# 9    2          16.0           2.0  18.0          14.0          17.5
# 10   2          21.0           2.0  24.5          16.5          21.0
#
#     Ref_5x5_90th  RefComposite  RefComposite_5x5_10th  RefComposite_5x5_50th  \
# 6           10.5          15.0                   10.5                   16.5
# 7           31.5          26.5                   26.5                   28.5
# 8           25.0          26.5                   23.5                   25.0
# 9           21.0          20.5                   18.0                   20.5
# 10          24.5          24.5                   21.0                   24.0
#
#     ...  RhoHV_5x5_90th     Zdr  Zdr_5x5_10th  Zdr_5x5_50th  Zdr_5x5_90th  \
# 6   ...        0.998333  0.3750       -0.1250        0.3125        0.8750
# 7   ...        1.005000  0.0625       -0.1875        0.2500        0.6875
# 8   ...        1.001667  0.3125       -0.0625        0.3125        0.6250
# 9   ...        1.001667  0.2500        0.1250        0.3750        0.6875
# 10  ...        0.998333  0.2500        0.0625        0.1875        0.5625
#
#          Kdp  Kdp_5x5_10th  Kdp_5x5_50th  Kdp_5x5_90th  Expected
# 6   1.059998     -1.410004     -0.350006      1.059998  1.016001
# 7        NaN           NaN           NaN      1.409988  1.016001
# 8   0.349991           NaN     -0.350006      1.759995  1.016001
# 9   0.349991     -1.059998      0.000000      1.059998  1.016001
# 10 -0.350006     -1.059998     -0.350006      1.759995  1.016001
#
# [5 rows x 24 columns]

# %%
train_new = train_new.fillna(0.0)
train_new = train_new.reset_index(drop=True)
train_new.head()
# Out:
#    Id  minutes_past  radardist_km   Ref  Ref_5x5_10th  Ref_5x5_50th  \
# 0   2           1.0           2.0   9.0           5.0           7.5
# 1   2           6.0           2.0  26.5          22.5          25.5
# 2   2          11.0           2.0  21.5          15.5          20.5
# 3   2          16.0           2.0  18.0          14.0          17.5
# 4   2          21.0           2.0  24.5          16.5          21.0
#
#    Ref_5x5_90th  RefComposite  RefComposite_5x5_10th  RefComposite_5x5_50th  \
# 0          10.5          15.0                   10.5                   16.5
# 1          31.5          26.5                   26.5                   28.5
# 2          25.0          26.5                   23.5                   25.0
# 3          21.0          20.5                   18.0                   20.5
# 4          24.5          24.5                   21.0                   24.0
#
#    ...  RhoHV_5x5_90th     Zdr  Zdr_5x5_10th  Zdr_5x5_50th  Zdr_5x5_90th  \
# 0  ...        0.998333  0.3750       -0.1250        0.3125        0.8750
# 1  ...        1.005000  0.0625       -0.1875        0.2500        0.6875
# 2  ...        1.001667  0.3125       -0.0625        0.3125        0.6250
# 3  ...        1.001667  0.2500        0.1250        0.3750        0.6875
# 4  ...        0.998333  0.2500        0.0625        0.1875        0.5625
#
#         Kdp  Kdp_5x5_10th  Kdp_5x5_50th  Kdp_5x5_90th  Expected
# 0  1.059998     -1.410004     -0.350006      1.059998  1.016001
# 1  0.000000      0.000000      0.000000      1.409988  1.016001
# 2  0.349991      0.000000     -0.350006      1.759995  1.016001
# 3  0.349991     -1.059998      0.000000      1.059998  1.016001
# 4 -0.350006     -1.059998     -0.350006      1.759995  1.016001
#
# [5 rows x 24 columns]

# %%
df_temp = pd.DataFrame(train_new.groupby('Id')['Expected'].mean()) # mean, or any value (the same for all)
meaningful_ids = np.array(df_temp[df_temp['Expected'] < THRESHOLD].index)
del df_temp

train_final = train_new[np.in1d(train_new.Id, meaningful_ids)]
del train_new, meaningful_ids
train_final.shape
# Out:
# (8926102, 24)

# %%
train_gp = train_final.groupby("Id")
train_size = len(train_gp)
del train_final

X_train = np.zeros((train_size, INPUT_WIDTH, N_FEATURES), dtype=np.float32)
y_train = np.zeros(train_size, dtype=np.float32)
seq_len_train = np.zeros(train_size, dtype=np.float32)

i = 0
for _, group in train_gp:
    X = group.values
    seq_len = X.shape[0]
    X_train[i,:seq_len,:] = X[:,1:23]
    y_train[i] = X[0,23]
    seq_len_train[i] = seq_len
    i += 1
    del X
    
del train_gp
X_train.shape, y_train.shape
# Out:
# ((714838, 19, 22), (714838,))

# %%
test_df = pd.read_csv("C:/Users/nikhi/Downloads/Rain/test/test.csv")
test_df[test_df.columns[1:]] = test_df[test_df.columns[1:]].astype(np.float32)
test_ids = np.array(test_df.Id.unique())

# Convert all NaNs to zero
test_final = test_df.fillna(0.0)
test_final = test_final.reset_index(drop=True)
del test_df

# %%
test_gp = test_final.groupby("Id")
test_size = len(test_gp)
del test_final

X_test = np.zeros((test_size, INPUT_WIDTH, N_FEATURES), dtype=np.float32)
seq_len_test = np.zeros(test_size, dtype=np.float32)

i = 0
for _, group in test_gp:
    X = group.values
    seq_len = X.shape[0]
    X_test[i,:seq_len,:] = X[:,1:23]
    seq_len_test[i] = seq_len
    i += 1
    del X
    
del test_gp
X_test.shape
# Out:
# (717625, 19, 22)

# %%
from keras.layers import Input, Dense, LSTM, AveragePooling1D,TimeDistributed, Flatten, Bidirectional
from keras.models import Model

# %%
from keras.callbacks import EarlyStopping
es_callback = EarlyStopping(monitor='val_loss', min_delta=0, patience=5)

# %%
X_train.shape
# Out:
# (714838, 19, 22)

# %%
BATCH_SIZE = 1024
N_EPOCHS = 50
def get_model_simple(shape=(19,22)):
    inp = Input(shape)
    x = LSTM(64, return_sequences=False)(inp)
    x = Dense(1)(x)

    model = Model(inp, x)
    return model
model_0 = get_model_simple((19,22))
model_0.compile(optimizer='adadelta', loss='mae')
model_0.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 19, 22)]          0
# _________________________________________________________________
# lstm (LSTM)                  (None, 64)                22272
# _________________________________________________________________
# dense (Dense)                (None, 1)                 65
# =================================================================
# Total params: 22,337
# Trainable params: 22,337
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_0.fit(X_train, y_train, 
            batch_size=BATCH_SIZE, epochs=N_EPOCHS, 
            validation_split=0.2, callbacks=[es_callback])
# Out:
# Epoch 1/50
# 559/559 [==============================] - 91s 164ms/step - loss: 3.1324 - val_loss: 3.1534
# Epoch 2/50
# 559/559 [==============================] - 82s 147ms/step - loss: 2.9878 - val_loss: 3.0344
# Epoch 3/50
# 559/559 [==============================] - 80s 144ms/step - loss: 2.8901 - val_loss: 2.9553
# Epoch 4/50
# 559/559 [==============================] - 76s 135ms/step - loss: 2.8233 - val_loss: 2.9041
# Epoch 5/50
# 559/559 [==============================] - 89s 159ms/step - loss: 2.7870 - val_loss: 2.8792
# Epoch 6/50
# 559/559 [==============================] - 85s 151ms/step - loss: 2.7675 - val_loss: 2.8637
# Epoch 7/50
# 559/559 [==============================] - 86s 154ms/step - loss: 2.7543 - val_loss: 2.8520
# Epoch 8/50
# 559/559 [==============================] - 88s 158ms/step - loss: 2.7439 - val_loss: 2.8425
# Epoch 9/50
# 559/559 [==============================] - 103s 185ms/step - loss: 2.7352 - val_loss: 2.8343
# Epoch 10/50
# 559/559 [==============================] - 112s 200ms/step - loss: 2.7274 - val_loss: 2.8270
# Epoch 11/50
# 559/559 [==============================] - 119s 213ms/step - loss: 2.7205 - val_loss: 2.8203
# Epoch 12/50
# 559/559 [==============================] - 119s 212ms/step - loss: 2.7141 - val_loss: 2.8141
# Epoch 13/50
# 559/559 [==============================] - 116s 207ms/step - loss: 2.7080 - val_loss: 2.8082
# Epoch 14/50
# 559/559 [==============================] - 114s 204ms/step - loss: 2.7022 - val_loss: 2.8027
# Epoch 15/50
# 559/559 [==============================] - 117s 209ms/step - loss: 2.6969 - val_loss: 2.7975
# Epoch 16/50
# 559/559 [==============================] - 96s 171ms/step - loss: 2.6917 - val_loss: 2.7926
# Epoch 17/50
# 559/559 [==============================] - 75s 134ms/step - loss: 2.6868 - val_loss: 2.7879
# Epoch 18/50
# 559/559 [==============================] - 75s 134ms/step - loss: 2.6822 - val_loss: 2.7835
# Epoch 19/50
# 559/559 [==============================] - 76s 136ms/step - loss: 2.6778 - val_loss: 2.7792
# Epoch 20/50
# 559/559 [==============================] - 71s 127ms/step - loss: 2.6736 - val_loss: 2.7752
# Epoch 21/50
# 559/559 [==============================] - 70s 125ms/step - loss: 2.6696 - val_loss: 2.7713
# Epoch 22/50
# 559/559 [==============================] - 70s 125ms/step - loss: 2.6657 - val_loss: 2.7676
# Epoch 23/50
# 559/559 [==============================] - 71s 127ms/step - loss: 2.6621 - val_loss: 2.7641
# Epoch 24/50
# 559/559 [==============================] - 70s 125ms/step - loss: 2.6587 - val_loss: 2.7608
# Epoch 25/50
# 559/559 [==============================] - 70s 125ms/step - loss: 2.6554 - val_loss: 2.7576
# Epoch 26/50
# 559/559 [==============================] - 69s 124ms/step - loss: 2.6523 - val_loss: 2.7547
# Epoch 27/50
# 559/559 [==============================] - 70s 125ms/step - loss: 2.6493 - val_loss: 2.7518
# Epoch 28/50
# 559/559 [==============================] - 73s 131ms/step - loss: 2.6464 - val_loss: 2.7491
# Epoch 29/50
# 559/559 [==============================] - 93s 166ms/step - loss: 2.6437 - val_loss: 2.7465
# Epoch 30/50
# 559/559 [==============================] - 94s 169ms/step - loss: 2.6411 - val_loss: 2.7441
# Epoch 31/50
# 559/559 [==============================] - 92s 164ms/step - loss: 2.6387 - val_loss: 2.7418
# Epoch 32/50
# 559/559 [==============================] - 92s 165ms/step - loss: 2.6364 - val_loss: 2.7396
# Epoch 33/50
# 559/559 [==============================] - 89s 159ms/step - loss: 2.6342 - val_loss: 2.7374
# Epoch 34/50
# 559/559 [==============================] - 88s 158ms/step - loss: 2.6321 - val_loss: 2.7353
# Epoch 35/50
# 559/559 [==============================] - 89s 159ms/step - loss: 2.6300 - val_loss: 2.7334
# Epoch 36/50
# 559/559 [==============================] - 88s 157ms/step - loss: 2.6281 - val_loss: 2.7315
# Epoch 37/50
# 559/559 [==============================] - 88s 157ms/step - loss: 2.6263 - val_loss: 2.7297
# Epoch 38/50
# 559/559 [==============================] - 93s 167ms/step - loss: 2.6245 - val_loss: 2.7279
# Epoch 39/50
# 559/559 [==============================] - 75s 135ms/step - loss: 2.6227 - val_loss: 2.7261
# Epoch 40/50
# 559/559 [==============================] - 67s 120ms/step - loss: 2.6210 - val_loss: 2.7244
# Epoch 41/50
# 559/559 [==============================] - 67s 120ms/step - loss: 2.6193 - val_loss: 2.7227
# Epoch 42/50
# 559/559 [==============================] - 67s 120ms/step - loss: 2.6177 - val_loss: 2.7211
# Epoch 43/50
# 559/559 [==============================] - 67s 119ms/step - loss: 2.6161 - val_loss: 2.7195
# Epoch 44/50
# 559/559 [==============================] - 68s 121ms/step - loss: 2.6145 - val_loss: 2.7178
# Epoch 45/50
# 559/559 [==============================] - 69s 123ms/step - loss: 2.6129 - val_loss: 2.7163
# Epoch 46/50
# 559/559 [==============================] - 73s 130ms/step - loss: 2.6114 - val_loss: 2.7148
# Epoch 47/50
# 559/559 [==============================] - 70s 126ms/step - loss: 2.6099 - val_loss: 2.7132
# Epoch 48/50
# 559/559 [==============================] - 70s 125ms/step - loss: 2.6084 - val_loss: 2.7118
# Epoch 49/50
# 559/559 [==============================] - 73s 131ms/step - loss: 2.6070 - val_loss: 2.7103
# Epoch 50/50
# 559/559 [==============================] - 70s 125ms/step - loss: 2.6056 - val_loss: 2.7089

# %%
y_pred_0 = model_0.predict(X_test)
submission_0 = pd.DataFrame({'Id': test_ids, 'Expected': y_pred_0.reshape(-1)})
submission_0.to_csv('C:/Users/nikhi/Downloads/Rain/submission_0.csv', index=False)

# %%
def get_model_seq(shape=(19,22)):
    inp = Input(shape)
    x = LSTM(64, return_sequences=True)(inp)
    x = TimeDistributed(Dense(10))(x)
    x = Flatten()(x)
    x = Dense(1)(x)

    model = Model(inp, x)
    return model

# %%
model_1 = get_model_seq((19,22))
model_1.compile(optimizer='adadelta', loss='mae')
model_1.summary()
# Out:
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 19, 22)]          0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 19, 64)            22272
# _________________________________________________________________
# time_distributed (TimeDistri (None, 19, 10)            650
# _________________________________________________________________
# flatten (Flatten)            (None, 190)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 191
# =================================================================
# Total params: 23,113
# Trainable params: 23,113
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_1.fit(X_train, y_train, 
            batch_size=BATCH_SIZE, epochs=N_EPOCHS, 
            validation_split=0.2, callbacks=[es_callback])
# Out:
# Epoch 1/50
# 559/559 [==============================] - 82s 146ms/step - loss: 2.9336 - val_loss: 2.9713
# Epoch 2/50
# 559/559 [==============================] - 71s 128ms/step - loss: 2.8364 - val_loss: 2.9094
# Epoch 3/50
# 559/559 [==============================] - 71s 127ms/step - loss: 2.7927 - val_loss: 2.8800
# Epoch 4/50
# 559/559 [==============================] - 79s 141ms/step - loss: 2.7683 - val_loss: 2.8599
# Epoch 5/50
# 559/559 [==============================] - 81s 146ms/step - loss: 2.7500 - val_loss: 2.8437
# Epoch 6/50
# 559/559 [==============================] - 70s 125ms/step - loss: 2.7349 - val_loss: 2.8299
# Epoch 7/50
# 559/559 [==============================] - 70s 125ms/step - loss: 2.7218 - val_loss: 2.8176
# Epoch 8/50
# 559/559 [==============================] - 69s 124ms/step - loss: 2.7101 - val_loss: 2.8068
# Epoch 9/50
# 559/559 [==============================] - 71s 126ms/step - loss: 2.7003 - val_loss: 2.7982
# Epoch 10/50
# 559/559 [==============================] - 70s 126ms/step - loss: 2.6924 - val_loss: 2.7910
# Epoch 11/50
# 559/559 [==============================] - 69s 124ms/step - loss: 2.6858 - val_loss: 2.7848
# Epoch 12/50
# 559/559 [==============================] - 69s 123ms/step - loss: 2.6800 - val_loss: 2.7791
# Epoch 13/50
# 559/559 [==============================] - 70s 126ms/step - loss: 2.6747 - val_loss: 2.7739
# Epoch 14/50
# 559/559 [==============================] - 195s 349ms/step - loss: 2.6698 - val_loss: 2.7692
# Epoch 15/50
# 559/559 [==============================] - 80s 142ms/step - loss: 2.6653 - val_loss: 2.7648
# Epoch 16/50
# 559/559 [==============================] - 70s 125ms/step - loss: 2.6611 - val_loss: 2.7607
# Epoch 17/50
# 559/559 [==============================] - 70s 126ms/step - loss: 2.6573 - val_loss: 2.7571
# Epoch 18/50
# 559/559 [==============================] - 69s 124ms/step - loss: 2.6539 - val_loss: 2.7537
# Epoch 19/50
# 559/559 [==============================] - 71s 127ms/step - loss: 2.6507 - val_loss: 2.7505
# Epoch 20/50
# 559/559 [==============================] - 69s 124ms/step - loss: 2.6477 - val_loss: 2.7476
# Epoch 21/50
# 559/559 [==============================] - 69s 124ms/step - loss: 2.6449 - val_loss: 2.7448
# Epoch 22/50
# 559/559 [==============================] - 69s 123ms/step - loss: 2.6423 - val_loss: 2.7421
# Epoch 23/50
# 559/559 [==============================] - 69s 123ms/step - loss: 2.6398 - val_loss: 2.7396
# Epoch 24/50
# 559/559 [==============================] - 70s 124ms/step - loss: 2.6374 - val_loss: 2.7371
# Epoch 25/50
# 559/559 [==============================] - 68s 122ms/step - loss: 2.6351 - val_loss: 2.7348
# Epoch 26/50
# 559/559 [==============================] - 69s 123ms/step - loss: 2.6329 - val_loss: 2.7326
# Epoch 27/50
# 559/559 [==============================] - 69s 124ms/step - loss: 2.6308 - val_loss: 2.7305
# Epoch 28/50
# 559/559 [==============================] - 70s 126ms/step - loss: 2.6288 - val_loss: 2.7285
# Epoch 29/50
# 559/559 [==============================] - 71s 127ms/step - loss: 2.6269 - val_loss: 2.7265
# Epoch 30/50
# 559/559 [==============================] - 72s 129ms/step - loss: 2.6251 - val_loss: 2.7246
# Epoch 31/50
# 559/559 [==============================] - 69s 123ms/step - loss: 2.6233 - val_loss: 2.7228
# Epoch 32/50
# 559/559 [==============================] - 69s 123ms/step - loss: 2.6216 - val_loss: 2.7210
# Epoch 33/50
# 559/559 [==============================] - 69s 123ms/step - loss: 2.6199 - val_loss: 2.7193
# Epoch 34/50
# 559/559 [==============================] - 69s 124ms/step - loss: 2.6183 - val_loss: 2.7177
# Epoch 35/50
# 559/559 [==============================] - 69s 124ms/step - loss: 2.6167 - val_loss: 2.7160
# Epoch 36/50
# 559/559 [==============================] - 69s 124ms/step - loss: 2.6151 - val_loss: 2.7145
# Epoch 37/50
# 559/559 [==============================] - 69s 124ms/step - loss: 2.6136 - val_loss: 2.7130
# Epoch 38/50
# 559/559 [==============================] - 69s 124ms/step - loss: 2.6122 - val_loss: 2.7115
# Epoch 39/50
# 559/559 [==============================] - 70s 124ms/step - loss: 2.6107 - val_loss: 2.7100
# Epoch 40/50
# 559/559 [==============================] - 72s 129ms/step - loss: 2.6093 - val_loss: 2.7086
# Epoch 41/50
# 559/559 [==============================] - 69s 123ms/step - loss: 2.6079 - val_loss: 2.7072
# Epoch 42/50
# 559/559 [==============================] - 69s 123ms/step - loss: 2.6065 - val_loss: 2.7058
# Epoch 43/50
# 559/559 [==============================] - 71s 126ms/step - loss: 2.6052 - val_loss: 2.7044
# Epoch 44/50
# 559/559 [==============================] - 69s 124ms/step - loss: 2.6038 - val_loss: 2.7031
# Epoch 45/50
# 559/559 [==============================] - 69s 124ms/step - loss: 2.6025 - val_loss: 2.7018
# Epoch 46/50
# 559/559 [==============================] - 69s 123ms/step - loss: 2.6012 - val_loss: 2.7005
# Epoch 47/50
# 559/559 [==============================] - 69s 124ms/step - loss: 2.5999 - val_loss: 2.6992
# Epoch 48/50
# 559/559 [==============================] - 69s 123ms/step - loss: 2.5986 - val_loss: 2.6980
# Epoch 49/50
# 559/559 [==============================] - 69s 124ms/step - loss: 2.5974 - val_loss: 2.6968
# Epoch 50/50
# 559/559 [==============================] - 71s 127ms/step - loss: 2.5962 - val_loss: 2.6956

# %%
y_pred_1 = model_1.predict(X_test)
submission_1 = pd.DataFrame({'Id': test_ids, 'Expected': y_pred_1.reshape(-1)})
submission_1.to_csv('C:/Users/nikhi/Downloads/Rain/submission_1.csv', index=False)

# %%
def get_model_bilstm(shape=(19,22)):
    inp = Input(shape)
    x = Bidirectional(LSTM(64, return_sequences=True))(inp)
    x = TimeDistributed(Dense(10))(x)
    x = Flatten()(x)
    x = Dense(1)(x)
    model = Model(inp, x)
    return model

# %%
model_2 = get_model_bilstm((19,22))
model_2.compile(optimizer='adadelta', loss='mae')
model_2.summary()
# Out:
# Model: "functional_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 19, 22)]          0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 19, 128)           44544
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 19, 10)            1290
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 190)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 191
# =================================================================
# Total params: 46,025
# Trainable params: 46,025
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_2.fit(X_train, y_train, 
            batch_size=BATCH_SIZE, epochs=N_EPOCHS, 
            validation_split=0.2, callbacks=[es_callback])
# Out:
# Epoch 1/50
# 559/559 [==============================] - 148s 265ms/step - loss: 2.8008 - val_loss: 2.8802
# Epoch 2/50
# 559/559 [==============================] - 160s 286ms/step - loss: 2.7637 - val_loss: 2.8499
# Epoch 3/50
# 559/559 [==============================] - 126s 226ms/step - loss: 2.7361 - val_loss: 2.8246
# Epoch 4/50
# 559/559 [==============================] - 132s 236ms/step - loss: 2.7130 - val_loss: 2.8037
# Epoch 5/50
# 559/559 [==============================] - 126s 225ms/step - loss: 2.6941 - val_loss: 2.7872
# Epoch 6/50
# 559/559 [==============================] - 126s 225ms/step - loss: 2.6792 - val_loss: 2.7741
# Epoch 7/50
# 559/559 [==============================] - 125s 223ms/step - loss: 2.6672 - val_loss: 2.7634
# Epoch 8/50
# 559/559 [==============================] - 142s 254ms/step - loss: 2.6574 - val_loss: 2.7546
# Epoch 9/50
# 559/559 [==============================] - 163s 291ms/step - loss: 2.6494 - val_loss: 2.7473
# Epoch 10/50
# 559/559 [==============================] - 141s 253ms/step - loss: 2.6426 - val_loss: 2.7410
# Epoch 11/50
# 559/559 [==============================] - 150s 267ms/step - loss: 2.6367 - val_loss: 2.7355
# Epoch 12/50
# 559/559 [==============================] - 146s 261ms/step - loss: 2.6316 - val_loss: 2.7306
# Epoch 13/50
# 559/559 [==============================] - 148s 265ms/step - loss: 2.6270 - val_loss: 2.7263
# Epoch 14/50
# 559/559 [==============================] - 148s 265ms/step - loss: 2.6229 - val_loss: 2.7224
# Epoch 15/50
# 559/559 [==============================] - 143s 255ms/step - loss: 2.6192 - val_loss: 2.7189
# Epoch 16/50
# 559/559 [==============================] - 149s 266ms/step - loss: 2.6158 - val_loss: 2.7156
# Epoch 17/50
# 559/559 [==============================] - 151s 270ms/step - loss: 2.6126 - val_loss: 2.7125
# Epoch 18/50
# 559/559 [==============================] - 149s 266ms/step - loss: 2.6096 - val_loss: 2.7096
# Epoch 19/50
# 559/559 [==============================] - 149s 266ms/step - loss: 2.6068 - val_loss: 2.7069
# Epoch 20/50
# 559/559 [==============================] - 148s 265ms/step - loss: 2.6041 - val_loss: 2.7042
# Epoch 21/50
# 559/559 [==============================] - 147s 263ms/step - loss: 2.6015 - val_loss: 2.7017
# Epoch 22/50
# 559/559 [==============================] - 136s 244ms/step - loss: 2.5990 - val_loss: 2.6993
# Epoch 23/50
# 559/559 [==============================] - 121s 216ms/step - loss: 2.5966 - val_loss: 2.6969
# Epoch 24/50
# 559/559 [==============================] - 121s 217ms/step - loss: 2.5943 - val_loss: 2.6946
# Epoch 25/50
# 559/559 [==============================] - 150s 269ms/step - loss: 2.5920 - val_loss: 2.6924
# Epoch 26/50
# 559/559 [==============================] - 148s 264ms/step - loss: 2.5898 - val_loss: 2.6902
# Epoch 27/50
# 559/559 [==============================] - 150s 268ms/step - loss: 2.5876 - val_loss: 2.6881
# Epoch 28/50
# 559/559 [==============================] - 152s 272ms/step - loss: 2.5855 - val_loss: 2.6860
# Epoch 29/50
# 559/559 [==============================] - 148s 264ms/step - loss: 2.5834 - val_loss: 2.6839
# Epoch 30/50
# 559/559 [==============================] - 149s 267ms/step - loss: 2.5813 - val_loss: 2.6819
# Epoch 31/50
# 559/559 [==============================] - 163s 291ms/step - loss: 2.5793 - val_loss: 2.6798
# Epoch 32/50
# 559/559 [==============================] - 160s 286ms/step - loss: 2.5772 - val_loss: 2.6778
# Epoch 33/50
# 559/559 [==============================] - 152s 272ms/step - loss: 2.5752 - val_loss: 2.6758
# Epoch 34/50
# 559/559 [==============================] - 129s 230ms/step - loss: 2.5733 - val_loss: 2.6739
# Epoch 35/50
# 559/559 [==============================] - 127s 226ms/step - loss: 2.5714 - val_loss: 2.6720
# Epoch 36/50
# 559/559 [==============================] - 128s 228ms/step - loss: 2.5694 - val_loss: 2.6700
# Epoch 37/50
# 559/559 [==============================] - 130s 233ms/step - loss: 2.5675 - val_loss: 2.6682
# Epoch 38/50
# 559/559 [==============================] - 165s 295ms/step - loss: 2.5657 - val_loss: 2.6664
# Epoch 39/50
# 559/559 [==============================] - 153s 274ms/step - loss: 2.5639 - val_loss: 2.6645
# Epoch 40/50
# 559/559 [==============================] - 151s 270ms/step - loss: 2.5622 - val_loss: 2.6628
# Epoch 41/50
# 559/559 [==============================] - 154s 275ms/step - loss: 2.5605 - val_loss: 2.6612
# Epoch 42/50
# 559/559 [==============================] - 156s 279ms/step - loss: 2.5589 - val_loss: 2.6595
# Epoch 43/50
# 559/559 [==============================] - 152s 273ms/step - loss: 2.5573 - val_loss: 2.6579
# Epoch 44/50
# 559/559 [==============================] - 148s 265ms/step - loss: 2.5558 - val_loss: 2.6564
# Epoch 45/50
# 559/559 [==============================] - 124s 221ms/step - loss: 2.5543 - val_loss: 2.6549
# Epoch 46/50
# 559/559 [==============================] - 136s 244ms/step - loss: 2.5529 - val_loss: 2.6535
# Epoch 47/50
# 559/559 [==============================] - 156s 279ms/step - loss: 2.5515 - val_loss: 2.6521
# Epoch 48/50
# 559/559 [==============================] - 146s 261ms/step - loss: 2.5501 - val_loss: 2.6507
# Epoch 49/50
# 559/559 [==============================] - 159s 284ms/step - loss: 2.5488 - val_loss: 2.6494
# Epoch 50/50
# 559/559 [==============================] - 159s 284ms/step - loss: 2.5476 - val_loss: 2.6481

# %%
y_pred_2 = model_2.predict(X_test)
submission_2 = pd.DataFrame({'Id': test_ids, 'Expected': y_pred_2.reshape(-1)})
submission_2.to_csv('C:/Users/nikhi/Downloads/Rain/submission_2.csv', index=False)

# %%
def get_model_deep(shape=(19,22)):
    inp = Input(shape)
    x = Dense(16)(inp)
    x = Bidirectional(LSTM(64, return_sequences=True))(x)
    x = TimeDistributed(Dense(64))(x)
    x = Bidirectional(LSTM(128, return_sequences=True))(x)
    x = TimeDistributed(Dense(1))(x)
    x = AveragePooling1D()(x)
    x = Flatten()(x)
    x = Dense(1)(x)

    model = Model(inp, x)
    return model

# %%
model_3 = get_model_deep((19,22))
model_3.compile(optimizer='adadelta', loss='mae')
model_3.summary()
# Out:
# Model: "functional_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 19, 22)]          0
# _________________________________________________________________
# dense_5 (Dense)              (None, 19, 16)            368
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 19, 128)           41472
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 19, 64)            8256
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 19, 256)           197632
# _________________________________________________________________
# time_distributed_3 (TimeDist (None, 19, 1)             257
# _________________________________________________________________
# average_pooling1d (AveragePo (None, 9, 1)              0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 9)                 0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 10
# =================================================================
# Total params: 247,995
# Trainable params: 247,995
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_3.fit(X_train, y_train, 
            batch_size=BATCH_SIZE, epochs=N_EPOCHS, 
            validation_split=0.2, callbacks=[es_callback])
# Out:
# Epoch 1/50
# 559/559 [==============================] - 547s 978ms/step - loss: 2.9481 - val_loss: 2.9079
# Epoch 2/50
# 559/559 [==============================] - 515s 922ms/step - loss: 2.7675 - val_loss: 2.8379
# Epoch 3/50
# 559/559 [==============================] - 506s 905ms/step - loss: 2.7178 - val_loss: 2.7976
# Epoch 4/50
# 559/559 [==============================] - 507s 906ms/step - loss: 2.6823 - val_loss: 2.7672
# Epoch 5/50
# 559/559 [==============================] - 632s 1s/step - loss: 2.6568 - val_loss: 2.7470
# Epoch 6/50
# 559/559 [==============================] - 572s 1s/step - loss: 2.6399 - val_loss: 2.7334
# Epoch 7/50
# 559/559 [==============================] - 526s 941ms/step - loss: 2.6281 - val_loss: 2.7234
# Epoch 8/50
# 559/559 [==============================] - 512s 915ms/step - loss: 2.6192 - val_loss: 2.7157
# Epoch 9/50
# 559/559 [==============================] - 509s 910ms/step - loss: 2.6120 - val_loss: 2.7092
# Epoch 10/50
# 559/559 [==============================] - 538s 962ms/step - loss: 2.6060 - val_loss: 2.7038
# Epoch 11/50
# 559/559 [==============================] - 517s 926ms/step - loss: 2.6009 - val_loss: 2.6990
# Epoch 12/50
# 559/559 [==============================] - 518s 927ms/step - loss: 2.5964 - val_loss: 2.6948
# Epoch 13/50
# 559/559 [==============================] - 550s 983ms/step - loss: 2.5924 - val_loss: 2.6911
# Epoch 14/50
# 559/559 [==============================] - 509s 911ms/step - loss: 2.5887 - val_loss: 2.6877
# Epoch 15/50
# 559/559 [==============================] - 507s 908ms/step - loss: 2.5853 - val_loss: 2.6843
# Epoch 16/50
# 559/559 [==============================] - 516s 924ms/step - loss: 2.5822 - val_loss: 2.6813
# Epoch 17/50
# 559/559 [==============================] - 507s 906ms/step - loss: 2.5792 - val_loss: 2.6784
# Epoch 18/50
# 559/559 [==============================] - 506s 905ms/step - loss: 2.5763 - val_loss: 2.6756
# Epoch 19/50
# 559/559 [==============================] - 507s 907ms/step - loss: 2.5736 - val_loss: 2.6729
# Epoch 20/50
# 559/559 [==============================] - 506s 905ms/step - loss: 2.5710 - val_loss: 2.6704
# Epoch 21/50
# 559/559 [==============================] - 506s 905ms/step - loss: 2.5685 - val_loss: 2.6680
# Epoch 22/50
# 559/559 [==============================] - 505s 904ms/step - loss: 2.5660 - val_loss: 2.6656
# Epoch 23/50
# 559/559 [==============================] - 505s 903ms/step - loss: 2.5636 - val_loss: 2.6632
# Epoch 24/50
# 559/559 [==============================] - 504s 902ms/step - loss: 2.5612 - val_loss: 2.6609
# Epoch 25/50
# 559/559 [==============================] - 505s 904ms/step - loss: 2.5590 - val_loss: 2.6587
# Epoch 26/50
# 559/559 [==============================] - 507s 907ms/step - loss: 2.5568 - val_loss: 2.6566
# Epoch 27/50
# 559/559 [==============================] - 504s 902ms/step - loss: 2.5545 - val_loss: 2.6545
# Epoch 28/50
# 559/559 [==============================] - 508s 910ms/step - loss: 2.5524 - val_loss: 2.6523
# Epoch 29/50
# 559/559 [==============================] - 503s 901ms/step - loss: 2.5503 - val_loss: 2.6504
# Epoch 30/50
# 559/559 [==============================] - 505s 904ms/step - loss: 2.5482 - val_loss: 2.6482
# Epoch 31/50
# 559/559 [==============================] - 504s 902ms/step - loss: 2.5462 - val_loss: 2.6462
# Epoch 32/50
# 559/559 [==============================] - 504s 902ms/step - loss: 2.5442 - val_loss: 2.6442
# Epoch 33/50
# 559/559 [==============================] - 512s 915ms/step - loss: 2.5423 - val_loss: 2.6424
# Epoch 34/50
# 559/559 [==============================] - 511s 913ms/step - loss: 2.5404 - val_loss: 2.6405
# Epoch 35/50
# 559/559 [==============================] - 507s 907ms/step - loss: 2.5385 - val_loss: 2.6386
# Epoch 36/50
# 559/559 [==============================] - 506s 905ms/step - loss: 2.5367 - val_loss: 2.6368
# Epoch 37/50
# 559/559 [==============================] - 511s 913ms/step - loss: 2.5348 - val_loss: 2.6351
# Epoch 38/50
# 559/559 [==============================] - 515s 921ms/step - loss: 2.5330 - val_loss: 2.6332
# Epoch 39/50
# 559/559 [==============================] - 505s 904ms/step - loss: 2.5312 - val_loss: 2.6315
# Epoch 40/50
# 559/559 [==============================] - 507s 908ms/step - loss: 2.5295 - val_loss: 2.6298
# Epoch 41/50
# 559/559 [==============================] - 505s 903ms/step - loss: 2.5278 - val_loss: 2.6281
# Epoch 42/50
# 559/559 [==============================] - 505s 903ms/step - loss: 2.5260 - val_loss: 2.6264
# Epoch 43/50
# 559/559 [==============================] - 505s 904ms/step - loss: 2.5244 - val_loss: 2.6249
# Epoch 44/50
# 559/559 [==============================] - 513s 918ms/step - loss: 2.5227 - val_loss: 2.6230
# Epoch 45/50
# 559/559 [==============================] - 506s 906ms/step - loss: 2.5211 - val_loss: 2.6215
# Epoch 46/50
# 559/559 [==============================] - 504s 902ms/step - loss: 2.5195 - val_loss: 2.6202
# Epoch 47/50
# 559/559 [==============================] - 517s 925ms/step - loss: 2.5180 - val_loss: 2.6182
# Epoch 48/50
# 559/559 [==============================] - 505s 903ms/step - loss: 2.5165 - val_loss: 2.6168
# Epoch 49/50
# 559/559 [==============================] - 506s 904ms/step - loss: 2.5149 - val_loss: 2.6153
# Epoch 50/50
# 559/559 [==============================] - 515s 921ms/step - loss: 2.5134 - val_loss: 2.6137

# %%
y_pred_3 = model_3.predict(X_test)
submission_3 = pd.DataFrame({'Id': test_ids, 'Expected': y_pred_3.reshape(-1)})
submission_3.to_csv('C:/Users/nikhi/Downloads/Rain/submission_3.csv', index=False)
