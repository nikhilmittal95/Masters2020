# %%
from google.colab import files
c= files.upload()
# Out:
#      <input type="file" id="files-723d5a43-8be5-4eb5-8272-cce8004dfaca" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-723d5a43-8be5-4eb5-8272-cce8004dfaca">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving heart_failure_clinical_records_dataset.csv to heart_failure_clinical_records_dataset.csv

# %%
import numpy as np # linear algebra
import pandas as pd

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from sklearn import svm 
from keras.layers import Dense, BatchNormalization, Dropout, LSTM
from keras.models import Sequential
from keras import callbacks

from sklearn.metrics import precision_score, recall_score, confusion_matrix, classification_report, accuracy_score, f1_score

# %%
data_df = pd.read_csv("heart_failure_clinical_records_dataset.csv")
data_df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# 2        1     7            1
# 3        0     7            1
# 4        0     8            1

# %%
#Evaluating the target and finding out the potential skewness in the data
cols= ["#CD5C5C","#FF0000"]
ax = sns.countplot(x= data_df["DEATH_EVENT"], palette= cols)
ax.bar_label(ax.containers[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-735d5c4aee5b> in <module>()
#       2 cols= ["#CD5C5C","#FF0000"]
#       3 ax = sns.countplot(x= data_df["DEATH_EVENT"], palette= cols)
# ----> 4 ax.bar_label(ax.containers[0])
#
# AttributeError: 'AxesSubplot' object has no attribute 'bar_label'

# %%
cmap = sns.diverging_palette(2, 165, s=80, l=55, n=9)
corrmat = data_df.corr()
plt.subplots(figsize=(20,20))
sns.heatmap(corrmat,cmap= cmap,annot=True, square=True)

# %%
plt.figure(figsize=(15,10))
Days_of_week=sns.countplot(x=data_df['age'],data=data_df, hue ="DEATH_EVENT",palette = cols)
Days_of_week.set_title("Distribution Of Age", color="#774571")
# Out:
# Text(0.5, 1.0, 'Distribution Of Age')

# %%
sns.kdeplot(x=data_df["time"], y=data_df["age"], hue =data_df["DEATH_EVENT"], palette=cols)

# %%
X=data_df.drop(["DEATH_EVENT"],axis=1)
y=data_df["DEATH_EVENT"]
# Setting up a standard scaler for the features and analyzing it thereafter
col_names = list(X.columns)
s_scaler = preprocessing.StandardScaler()
X_scaled= s_scaler.fit_transform(X)
X_scaled = pd.DataFrame(X_scaled, columns=col_names)   
X_scaled.describe().T
# Out:
#                           count          mean       std       min       25%  \
# age                       299.0  5.265205e-16  1.001676 -1.754448 -0.828124
# anaemia                   299.0  3.594301e-16  1.001676 -0.871105 -0.871105
# creatinine_phosphokinase  299.0  3.713120e-18  1.001676 -0.576918 -0.480393
# diabetes                  299.0  1.113936e-16  1.001676 -0.847579 -0.847579
# ejection_fraction         299.0  3.341808e-18  1.001676 -2.038387 -0.684180
# high_blood_pressure       299.0 -4.841909e-16  1.001676 -0.735688 -0.735688
# platelets                 299.0  1.009969e-16  1.001676 -2.440155 -0.520870
# serum_creatinine          299.0 -2.227872e-18  1.001676 -0.865509 -0.478205
# serum_sodium              299.0 -8.627435e-16  1.001676 -5.363206 -0.595996
# sex                       299.0 -5.940993e-18  1.001676 -1.359272 -1.359272
# smoking                   299.0 -3.861645e-17  1.001676 -0.687682 -0.687682
# time                      299.0 -1.069379e-16  1.001676 -1.629502 -0.739000
#
#                                50%       75%       max
# age                      -0.070223  0.771889  2.877170
# anaemia                  -0.871105  1.147968  1.147968
# creatinine_phosphokinase -0.342574  0.000166  7.514640
# diabetes                 -0.847579  1.179830  1.179830
# ejection_fraction        -0.007077  0.585389  3.547716
# high_blood_pressure      -0.735688  1.359272  1.359272
# platelets                -0.013908  0.411120  6.008180
# serum_creatinine         -0.284552  0.005926  7.752020
# serum_sodium              0.085034  0.766064  2.582144
# sex                       0.735688  0.735688  0.735688
# smoking                  -0.687682  1.454161  1.454161
# time                     -0.196954  0.938759  1.997038

# %%
colors =["#CD5C5C","#F08080","#FA8072","#E9967A","#FFA07A"]
plt.figure(figsize=(20,10))
sns.boxenplot(data = X_scaled,palette = colors)
plt.xticks(rotation=60)
plt.show()

# %%
X_train, X_test, y_train,y_test = train_test_split(X_scaled,y,test_size=0.30,random_state=25)

# %%
# Instantiating the SVM algorithm 
model1=svm.SVC()

# Fitting the model 
model1.fit (X_train, y_train)

# Predicting the test variables
y_pred = model1.predict(X_test)

# Getting the score 
model1.score (X_test, y_test)
# Out:
# 0.7888888888888889

# %%
early_stopping = callbacks.EarlyStopping(
    min_delta=0.001, # minimium amount of change to count as an improvement
    patience=20, # how many epochs to wait before stopping
    restore_best_weights=True)

# Initialising the NN
model = Sequential()

# layers
model.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu', input_dim = 12))
model.add(Dense(units = 8, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dropout(0.25))
model.add(Dense(units = 8, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# Compiling the ANN
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# Train the ANN
history = model.fit(X_train, y_train, batch_size = 25, epochs = 80,callbacks=[early_stopping], validation_split=0.25)
# Out:
# Epoch 1/80
# 7/7 [==============================] - 2s 78ms/step - loss: 0.6927 - accuracy: 0.6474 - val_loss: 0.6906 - val_accuracy: 0.8302
# Epoch 2/80
# 7/7 [==============================] - 0s 21ms/step - loss: 0.6918 - accuracy: 0.6346 - val_loss: 0.6881 - val_accuracy: 0.8302
# Epoch 3/80
# 7/7 [==============================] - 0s 14ms/step - loss: 0.6908 - accuracy: 0.6346 - val_loss: 0.6857 - val_accuracy: 0.8302
# Epoch 4/80
# 7/7 [==============================] - 0s 14ms/step - loss: 0.6897 - accuracy: 0.6346 - val_loss: 0.6832 - val_accuracy: 0.8302
# Epoch 5/80
# 7/7 [==============================] - 0s 14ms/step - loss: 0.6886 - accuracy: 0.6346 - val_loss: 0.6806 - val_accuracy: 0.8302
# Epoch 6/80
# 7/7 [==============================] - 0s 15ms/step - loss: 0.6873 - accuracy: 0.6346 - val_loss: 0.6775 - val_accuracy: 0.8302
# Epoch 7/80
# 7/7 [==============================] - 0s 12ms/step - loss: 0.6858 - accuracy: 0.6346 - val_loss: 0.6736 - val_accuracy: 0.8302
# Epoch 8/80
# 7/7 [==============================] - 0s 12ms/step - loss: 0.6831 - accuracy: 0.6346 - val_loss: 0.6689 - val_accuracy: 0.8302
# Epoch 9/80
# 7/7 [==============================] - 0s 12ms/step - loss: 0.6803 - accuracy: 0.6346 - val_loss: 0.6626 - val_accuracy: 0.8302
# Epoch 10/80
# 7/7 [==============================] - 0s 12ms/step - loss: 0.6753 - accuracy: 0.6346 - val_loss: 0.6546 - val_accuracy: 0.8302
# Epoch 11/80
# 7/7 [==============================] - 0s 12ms/step - loss: 0.6705 - accuracy: 0.6346 - val_loss: 0.6441 - val_accuracy: 0.8302
# Epoch 12/80
# 7/7 [==============================] - 0s 17ms/step - loss: 0.6624 - accuracy: 0.6346 - val_loss: 0.6318 - val_accuracy: 0.8302
# Epoch 13/80
# 7/7 [==============================] - 0s 14ms/step - loss: 0.6540 - accuracy: 0.6346 - val_loss: 0.6162 - val_accuracy: 0.8302
# Epoch 14/80
# 7/7 [==============================] - 0s 14ms/step - loss: 0.6359 - accuracy: 0.6346 - val_loss: 0.5957 - val_accuracy: 0.8302
# Epoch 15/80
# 7/7 [==============================] - 0s 14ms/step - loss: 0.6216 - accuracy: 0.6346 - val_loss: 0.5695 - val_accuracy: 0.8302
# Epoch 16/80
# 7/7 [==============================] - 0s 17ms/step - loss: 0.6104 - accuracy: 0.6346 - val_loss: 0.5442 - val_accuracy: 0.8302
# Epoch 17/80
# 7/7 [==============================] - 0s 16ms/step - loss: 0.5888 - accuracy: 0.6346 - val_loss: 0.5151 - val_accuracy: 0.8302
# Epoch 18/80
# 7/7 [==============================] - 0s 13ms/step - loss: 0.5715 - accuracy: 0.6346 - val_loss: 0.4810 - val_accuracy: 0.8302
# Epoch 19/80
# 7/7 [==============================] - 0s 23ms/step - loss: 0.5465 - accuracy: 0.6346 - val_loss: 0.4481 - val_accuracy: 0.8302
# Epoch 20/80
# 7/7 [==============================] - 0s 33ms/step - loss: 0.5451 - accuracy: 0.6346 - val_loss: 0.4203 - val_accuracy: 0.8302
# Epoch 21/80
# 7/7 [==============================] - 0s 22ms/step - loss: 0.5300 - accuracy: 0.6346 - val_loss: 0.3946 - val_accuracy: 0.8302
# Epoch 22/80
# 7/7 [==============================] - 0s 40ms/step - loss: 0.5144 - accuracy: 0.6346 - val_loss: 0.3762 - val_accuracy: 0.8302
# Epoch 23/80
# 7/7 [==============================] - 0s 44ms/step - loss: 0.4979 - accuracy: 0.6346 - val_loss: 0.3595 - val_accuracy: 0.8302
# Epoch 24/80
# 7/7 [==============================] - 0s 35ms/step - loss: 0.5020 - accuracy: 0.6346 - val_loss: 0.3445 - val_accuracy: 0.8302
# Epoch 25/80
# 7/7 [==============================] - 0s 11ms/step - loss: 0.4904 - accuracy: 0.6346 - val_loss: 0.3325 - val_accuracy: 0.8302
# Epoch 26/80
# 7/7 [==============================] - 0s 9ms/step - loss: 0.5181 - accuracy: 0.6346 - val_loss: 0.3297 - val_accuracy: 0.8302
# Epoch 27/80
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5094 - accuracy: 0.6346 - val_loss: 0.3287 - val_accuracy: 0.8302
# Epoch 28/80
# 7/7 [==============================] - 0s 11ms/step - loss: 0.4884 - accuracy: 0.6474 - val_loss: 0.3292 - val_accuracy: 0.8302
# Epoch 29/80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4880 - accuracy: 0.6795 - val_loss: 0.3316 - val_accuracy: 0.8302
# Epoch 30/80
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4995 - accuracy: 0.7051 - val_loss: 0.3317 - val_accuracy: 0.8491
# Epoch 31/80
# 7/7 [==============================] - 0s 9ms/step - loss: 0.4866 - accuracy: 0.7308 - val_loss: 0.3303 - val_accuracy: 0.8302
# Epoch 32/80
# 7/7 [==============================] - 0s 6ms/step - loss: 0.4724 - accuracy: 0.6923 - val_loss: 0.3249 - val_accuracy: 0.9057
# Epoch 33/80
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4693 - accuracy: 0.7244 - val_loss: 0.3180 - val_accuracy: 0.8868
# Epoch 34/80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4430 - accuracy: 0.7692 - val_loss: 0.3109 - val_accuracy: 0.8868
# Epoch 35/80
# 7/7 [==============================] - 0s 6ms/step - loss: 0.4709 - accuracy: 0.7179 - val_loss: 0.3104 - val_accuracy: 0.8868
# Epoch 36/80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4498 - accuracy: 0.7692 - val_loss: 0.3159 - val_accuracy: 0.9057
# Epoch 37/80
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4461 - accuracy: 0.7179 - val_loss: 0.3145 - val_accuracy: 0.8868
# Epoch 38/80
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4319 - accuracy: 0.7500 - val_loss: 0.3142 - val_accuracy: 0.8868
# Epoch 39/80
# 7/7 [==============================] - 0s 9ms/step - loss: 0.4233 - accuracy: 0.7436 - val_loss: 0.3097 - val_accuracy: 0.8868
# Epoch 40/80
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4474 - accuracy: 0.7885 - val_loss: 0.3068 - val_accuracy: 0.8868
# Epoch 41/80
# 7/7 [==============================] - 0s 6ms/step - loss: 0.4175 - accuracy: 0.7308 - val_loss: 0.3047 - val_accuracy: 0.8868
# Epoch 42/80
# 7/7 [==============================] - 0s 8ms/step - loss: 0.4356 - accuracy: 0.6987 - val_loss: 0.3015 - val_accuracy: 0.8868
# Epoch 43/80
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3996 - accuracy: 0.7821 - val_loss: 0.2957 - val_accuracy: 0.9057
# Epoch 44/80
# 7/7 [==============================] - 0s 6ms/step - loss: 0.4330 - accuracy: 0.7372 - val_loss: 0.2926 - val_accuracy: 0.9057
# Epoch 45/80
# 7/7 [==============================] - 0s 8ms/step - loss: 0.4119 - accuracy: 0.8013 - val_loss: 0.2934 - val_accuracy: 0.9057
# Epoch 46/80
# 7/7 [==============================] - 0s 9ms/step - loss: 0.4073 - accuracy: 0.7500 - val_loss: 0.2931 - val_accuracy: 0.9057
# Epoch 47/80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4015 - accuracy: 0.8397 - val_loss: 0.2943 - val_accuracy: 0.8679
# Epoch 48/80
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3999 - accuracy: 0.8397 - val_loss: 0.2967 - val_accuracy: 0.8491
# Epoch 49/80
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3870 - accuracy: 0.8269 - val_loss: 0.2958 - val_accuracy: 0.8302
# Epoch 50/80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3699 - accuracy: 0.8718 - val_loss: 0.2911 - val_accuracy: 0.8491
# Epoch 51/80
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3825 - accuracy: 0.8526 - val_loss: 0.2892 - val_accuracy: 0.8491
# Epoch 52/80
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3836 - accuracy: 0.8397 - val_loss: 0.2932 - val_accuracy: 0.8491
# Epoch 53/80
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4041 - accuracy: 0.8397 - val_loss: 0.2973 - val_accuracy: 0.8302
# Epoch 54/80
# 7/7 [==============================] - 0s 6ms/step - loss: 0.4001 - accuracy: 0.8397 - val_loss: 0.3001 - val_accuracy: 0.8302
# Epoch 55/80
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3720 - accuracy: 0.8590 - val_loss: 0.3011 - val_accuracy: 0.8302
# Epoch 56/80
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3982 - accuracy: 0.8141 - val_loss: 0.2983 - val_accuracy: 0.8302
# Epoch 57/80
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3864 - accuracy: 0.8526 - val_loss: 0.2960 - val_accuracy: 0.8302
# Epoch 58/80
# 7/7 [==============================] - 0s 11ms/step - loss: 0.3931 - accuracy: 0.8462 - val_loss: 0.2915 - val_accuracy: 0.8679
# Epoch 59/80
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3655 - accuracy: 0.8462 - val_loss: 0.2821 - val_accuracy: 0.8679
# Epoch 60/80
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3518 - accuracy: 0.8590 - val_loss: 0.2787 - val_accuracy: 0.8868
# Epoch 61/80
# 7/7 [==============================] - 0s 9ms/step - loss: 0.4140 - accuracy: 0.8526 - val_loss: 0.2755 - val_accuracy: 0.8868
# Epoch 62/80
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3695 - accuracy: 0.8141 - val_loss: 0.2776 - val_accuracy: 0.8868
# Epoch 63/80
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3664 - accuracy: 0.8397 - val_loss: 0.2813 - val_accuracy: 0.8491
# Epoch 64/80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3819 - accuracy: 0.8397 - val_loss: 0.2888 - val_accuracy: 0.8302
# Epoch 65/80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3630 - accuracy: 0.8590 - val_loss: 0.2908 - val_accuracy: 0.8302
# Epoch 66/80
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3878 - accuracy: 0.8397 - val_loss: 0.2924 - val_accuracy: 0.8302
# Epoch 67/80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3520 - accuracy: 0.8590 - val_loss: 0.2922 - val_accuracy: 0.8302
# Epoch 68/80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3622 - accuracy: 0.8654 - val_loss: 0.2912 - val_accuracy: 0.8302
# Epoch 69/80
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3474 - accuracy: 0.8654 - val_loss: 0.2881 - val_accuracy: 0.8302
# Epoch 70/80
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3807 - accuracy: 0.8654 - val_loss: 0.2845 - val_accuracy: 0.8302
# Epoch 71/80
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3730 - accuracy: 0.8654 - val_loss: 0.2817 - val_accuracy: 0.8302
# Epoch 72/80
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3534 - accuracy: 0.8718 - val_loss: 0.2783 - val_accuracy: 0.8491
# Epoch 73/80
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3523 - accuracy: 0.8526 - val_loss: 0.2763 - val_accuracy: 0.8491
# Epoch 74/80
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3588 - accuracy: 0.8141 - val_loss: 0.2756 - val_accuracy: 0.8679
# Epoch 75/80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3544 - accuracy: 0.8782 - val_loss: 0.2738 - val_accuracy: 0.8679
# Epoch 76/80
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3381 - accuracy: 0.8718 - val_loss: 0.2751 - val_accuracy: 0.8491
# Epoch 77/80
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3457 - accuracy: 0.8590 - val_loss: 0.2801 - val_accuracy: 0.8302
# Epoch 78/80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3623 - accuracy: 0.8269 - val_loss: 0.2806 - val_accuracy: 0.8302
# Epoch 79/80
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3442 - accuracy: 0.8590 - val_loss: 0.2815 - val_accuracy: 0.8302
# Epoch 80/80
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3249 - accuracy: 0.8846 - val_loss: 0.2820 - val_accuracy: 0.8491

# %%
val_accuracy = np.mean(history.history['val_accuracy'])
print("\n%s: %.2f%%" % ('val_accuracy is', val_accuracy*100))
# Out:
# val_accuracy is: 84.91%

# %%
history_df = pd.DataFrame(history.history)

plt.plot(history_df.loc[:, ['loss']], "#CD5C5C", label='Training loss')
plt.plot(history_df.loc[:, ['val_loss']],"#FF0000", label='Validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc="best")

plt.show()

# %%
history_df = pd.DataFrame(history.history)

plt.plot(history_df.loc[:, ['accuracy']], "#CD5C5C", label='Training accuracy')
plt.plot(history_df.loc[:, ['val_accuracy']],"#FF0000", label='Validation accuracy')

plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
