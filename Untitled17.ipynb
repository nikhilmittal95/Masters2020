# %%
from google.colab import files
l= files.upload()
# Out:
#      <input type="file" id="files-51fb110b-f931-475d-92a9-a79a158d6ff4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-51fb110b-f931-475d-92a9-a79a158d6ff4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving bhp.csv to bhp.csv

# %%
import pandas as pd

# %%
df= pd.read_csv("bhp.csv")

# %%
df.head()
# Out:
#                    location       size  total_sqft  ...   price  bhk  price_per_sqft
# 0  Electronic City Phase II      2 BHK      1056.0  ...   39.07    2            3699
# 1          Chikka Tirupathi  4 Bedroom      2600.0  ...  120.00    4            4615
# 2               Uttarahalli      3 BHK      1440.0  ...   62.00    3            4305
# 3        Lingadheeranahalli      3 BHK      1521.0  ...   95.00    3            6245
# 4                  Kothanur      2 BHK      1200.0  ...   51.00    2            4250
#
# [5 rows x 7 columns]

# %%
df.shape
# Out:
# (13200, 7)

# %%
df.describe()
# Out:
#          total_sqft          bath         price           bhk  price_per_sqft
# count  13200.000000  13200.000000  13200.000000  13200.000000    1.320000e+04
# mean    1555.302783      2.691136    112.276178      2.800833    7.920337e+03
# std     1237.323445      1.338915    149.175995      1.292843    1.067272e+05
# min        1.000000      1.000000      8.000000      1.000000    2.670000e+02
# 25%     1100.000000      2.000000     50.000000      2.000000    4.267000e+03
# 50%     1275.000000      2.000000     71.850000      3.000000    5.438000e+03
# 75%     1672.000000      3.000000    120.000000      3.000000    7.317000e+03
# max    52272.000000     40.000000   3600.000000     43.000000    1.200000e+07

# %%
min_thresold, max_thresold = df.price_per_sqft.quantile([0.001, 0.999])
min_thresold, max_thresold
# Out:
# (1366.184, 50959.36200000098)

# %%
df[df.price_per_sqft < min_thresold]
# Out:
#         location       size  total_sqft  bath  price  bhk  price_per_sqft
# 665    Yelahanka      3 BHK     35000.0   3.0  130.0    3             371
# 798        other  4 Bedroom     10961.0   4.0   80.0    4             729
# 1867       other  3 Bedroom     52272.0   2.0  140.0    3             267
# 2392       other  4 Bedroom      2000.0   3.0   25.0    4            1250
# 3934       other      1 BHK      1500.0   1.0   19.5    1            1300
# 5343       other      9 BHK     42000.0   8.0  175.0    9             416
# 5417      Ulsoor      4 BHK     36000.0   4.0  450.0    4            1250
# 5597    JP Nagar      2 BHK      1100.0   1.0   15.0    2            1363
# 7166   Yelahanka  1 Bedroom     26136.0   1.0  150.0    1             573
# 7862    JP Nagar      3 BHK     20000.0   3.0  175.0    3             875
# 8300     Kengeri      1 BHK      1200.0   1.0   14.0    1            1166
# 9144       other  4 Bedroom     10961.0   4.0   80.0    4             729
# 11635      Begur      3 BHK      2400.0   3.0   12.0    3             500
# 12355      other      4 BHK     16335.0   4.0  149.0    4             912

# %%
df2 = df[(df.price_per_sqft<max_thresold) & (df.price_per_sqft>min_thresold)]
df2.shape
# Out:
# (13172, 7)

# %%
from google.colab import files
pkpp= files.upload()
# Out:
#      <input type="file" id="files-7d752b49-af14-4786-995b-7b95455237a3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7d752b49-af14-4786-995b-7b95455237a3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving heights23.csv to heights23.csv

# %%
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (10,6)

# %%
df = pd.read_csv("heights23.csv")
df.sample(5)
# Out:
#      gender     height
# 4022   Male  66.134175
# 4923   Male  63.791446
# 382    Male  66.998290
# 3824   Male  71.448881
# 2586   Male  69.130038

# %%
df.head()
# Out:
#   gender     height
# 0   Male  73.847017
# 1   Male  68.781904
# 2   Male  74.110105
# 3   Male  71.730978
# 4   Male  69.881796

# %%
plt.hist(df.height, bins=20, rwidth=0.8)
plt.xlabel('Height (inches)')
plt.ylabel('Count')
plt.show()

# %%
from scipy.stats import norm
import numpy as np
plt.hist(df.height, bins=20, rwidth=0.8, density=True)
plt.xlabel('Height (inches)')
plt.ylabel('Count')

rng = np.arange(df.height.min(), df.height.max(), 0.1)
plt.plot(rng, norm.pdf(rng,df.height.mean(),df.height.std()))

# %%
upper_limit = df.height.mean() + 3*df.height.std()
upper_limit
# Out:
# 77.91014411725232

# %%
lower_limit = df.height.mean() -3*df.height.std()
lower_limit
# Out:
# 54.824975392478876

# %%
df[(df.height>upper_limit) | (df.height<lower_limit)]
# Out:
#       gender     height
# 994     Male  78.095867
# 1317    Male  78.462053
# 2014    Male  78.998742
# 3285    Male  78.528210
# 3757    Male  78.621374
# 6624  Female  54.616858
# 9285  Female  54.263133

# %%
df_no_outlier_std_dev = df[(df.height<upper_limit) & (df.height>lower_limit)]
df_no_outlier_std_dev.head()
# Out:
#   gender     height
# 0   Male  73.847017
# 1   Male  68.781904
# 2   Male  74.110105
# 3   Male  71.730978
# 4   Male  69.881796

# %%
df_no_outlier_std_dev.shape
# Out:
# (9993, 2)

# %%
df.shape
# Out:
# (10000, 2)

# %%
df['zscore'] = ( df.height - df.height.mean() ) / df.height.std()
df.head(5)
# Out:
#   gender     height    zscore
# 0   Male  73.847017  1.943964
# 1   Male  68.781904  0.627505
# 2   Male  74.110105  2.012343
# 3   Male  71.730978  1.393991
# 4   Male  69.881796  0.913375

# %%
df[df['zscore']>3]
# Out:
#      gender     height    zscore
# 994    Male  78.095867  3.048271
# 1317   Male  78.462053  3.143445
# 2014   Male  78.998742  3.282934
# 3285   Male  78.528210  3.160640
# 3757   Male  78.621374  3.184854

# %%
df[df['zscore']<-3]
# Out:
#       gender     height    zscore
# 6624  Female  54.616858 -3.054091
# 9285  Female  54.263133 -3.146027

# %%
df[(df.zscore<-3) | (df.zscore>3)]
# Out:
#       gender     height    zscore
# 994     Male  78.095867  3.048271
# 1317    Male  78.462053  3.143445
# 2014    Male  78.998742  3.282934
# 3285    Male  78.528210  3.160640
# 3757    Male  78.621374  3.184854
# 6624  Female  54.616858 -3.054091
# 9285  Female  54.263133 -3.146027

# %%
df_no_outliers = df[(df.zscore>-3) & (df.zscore<3)]
df_no_outliers.head()
# Out:
#   gender     height    zscore
# 0   Male  73.847017  1.943964
# 1   Male  68.781904  0.627505
# 2   Male  74.110105  2.012343
# 3   Male  71.730978  1.393991
# 4   Male  69.881796  0.913375

# %%
df_no_outliers.shape
# Out:
# (9993, 3)

# %%
df.shape
# Out:
# (10000, 3)

# %%
from google.colab import files
s= files.upload()
# Out:
#      <input type="file" id="files-dc6efbf7-3087-41ec-8707-5614dcb9a290" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dc6efbf7-3087-41ec-8707-5614dcb9a290">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 11.csv to 11.csv

# %%
#Outlier Detection and Removal Using IQR
import pandas as pd
df = pd.read_csv("heights.csv")
df
# Out:
#        name  height
# 0     mohan     5.9
# 1     maria     5.2
# 2     sakib     5.1
# 3       tao     5.5
# 4     virat     4.9
# 5    khusbu     5.4
# 6    dmitry     6.2
# 7    selena     6.5
# 8      john     7.1
# 9     imran    14.5
# 10     jose     6.1
# 11  deepika     5.6
# 12   yoseph     1.2
# 13    binod     5.5

# %%
df.describe()
# Out:
#           height
# count  14.000000
# mean    6.050000
# std     2.779804
# min     1.200000
# 25%     5.250000
# 50%     5.550000
# 75%     6.175000
# max    14.500000

# %%
Q1 = df.height.quantile(0.25)
Q3 = df.height.quantile(0.75)
Q1, Q3
# Out:
# (5.25, 6.175)

# %%
IQR = Q3 - Q1
IQR
# Out:
# 0.9249999999999998

# %%
lower_limit = Q1 - 1.5*IQR
upper_limit = Q3 + 1.5*IQR
lower_limit, upper_limit
# Out:
# (3.8625000000000003, 7.5625)

# %%
df[(df.height<lower_limit)|(df.height>upper_limit)]
# Out:
#       name  height
# 9    imran    14.5
# 12  yoseph     1.2

# %%
df_no_outlier = df[(df.height>lower_limit)&(df.height<upper_limit)]
df_no_outlier
# Out:
#        name  height
# 0     mohan     5.9
# 1     maria     5.2
# 2     sakib     5.1
# 3       tao     5.5
# 4     virat     4.9
# 5    khusbu     5.4
# 6    dmitry     6.2
# 7    selena     6.5
# 8      john     7.1
# 10     jose     6.1
# 11  deepika     5.6
# 13    binod     5.5
